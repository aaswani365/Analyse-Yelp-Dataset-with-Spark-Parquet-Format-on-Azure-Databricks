# %% [markdown]
# Set Azure Date Lake Storage configurations

# %%
spark.conf.set("fs.azure.account.key.stgrpgroupd.dfs.core.windows.net", "mmfD58xO9Q+2pZ5/ljm+6wNtQn8qCgxsE21fIbEvO2PPhd46HBKCp4rYsz6moBiMD/yvvevCWF+9+AStxIWVlQ==")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# List of DataSets in Azure DataLake

# %%
# %python
dbutils.fs.ls("abfss://sourcecontainer@stgrpgroupd.dfs.core.windows.net/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[67]: [FileInfo(path=&#39;abfss://sourcecontainer@stgrpgroupd.dfs.core.windows.net/yelp_academic_dataset_business.json&#39;, name=&#39;yelp_academic_dataset_business.json&#39;, size=118863795, modificationTime=1657618871000),
#  FileInfo(path=&#39;abfss://sourcecontainer@stgrpgroupd.dfs.core.windows.net/yelp_academic_dataset_checkin.json&#39;, name=&#39;yelp_academic_dataset_checkin.json&#39;, size=286958945, modificationTime=1657618868000),
# ...

# %% [markdown]
# Read the Yelp Datasets and Convert into the parquet format

# %%
# %python
df_business = spark.read.json("abfss://sourcecontainer@stgrpgroupd.dfs.core.windows.net/yelp_academic_dataset_business.json")
df_business.write.mode('overwrite').parquet("abfss://yelpdataset@stgrpgroupd.dfs.core.windows.net/json_to_parquet/business.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python
df_checkin = spark.read.json("abfss://yelpdataset@stgrpgroupd.dfs.core.windows.net/yelp_academic_dataset_checkin.json")
df_checkin.write.mode('overwrite').parquet("abfss://yelpdataset@stgrpgroupd.dfs.core.windows.net/json_to_parquet/checkin.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python
df_review = spark.read.json("abfss://yelpdataset@stgrpgroupd.dfs.core.windows.net/yelp_academic_dataset_review.json")
df_review.write.mode('overwrite').parquet("abfss://yelpdataset@stgrpgroupd.dfs.core.windows.net/json_to_parquet/review.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_tip = spark.read.json("abfss://yelpdataset@stgrpgroupd.dfs.core.windows.net/yelp_academic_dataset_tip.json")
df_tip.write.mode('overwrite').parquet("abfss://yelpdataset@stgrpgroupd.dfs.core.windows.net/json_to_parquet/tip.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_user = spark.read.json("abfss://yelpdataset@stgrpgroupd.dfs.core.windows.net/yelp_academic_dataset_user.json")
df_user.write.mode('overwrite').parquet("abfss://yelpdataset@stgrpgroupd.dfs.core.windows.net/json_to_parquet/user.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Convert to Delta Format

# %%
df_business.write.mode('overwrite').parquet("abfss://yelpdataset@stgrpgroupd.dfs.core.windows.net/parquet_to_delta/business.delta")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Read Parquet format File

# %%
df_business = spark.read.parquet("abfss://yelpdataset@stgrpgroupd.dfs.core.windows.net/json_to_parquet/business.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_checkin = spark.read.parquet("abfss://yelpdataset@stgrpgroupd.dfs.core.windows.net/json_to_parquet/checkin.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_review = spark.read.parquet("abfss://yelpdataset@stgrpgroupd.dfs.core.windows.net/json_to_parquet/review.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_tip = spark.read.parquet("abfss://yelpdataset@stgrpgroupd.dfs.core.windows.net/json_to_parquet/tip.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_user = spark.read.parquet("abfss://yelpdataset@stgrpgroupd.dfs.core.windows.net/json_to_parquet/user.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Print total records in each DF

# %%
print("df_business : "+ str(df_business.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">df_business : 150346
# </div>

# %%
print("df_checkin : "+ str(df_checkin.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">df_checkin : 131930
# </div>

# %%
print("df_review : "+ str(df_review.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">df_review : 6990280
# </div>

# %%
print("df_tip : "+ str(df_tip.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">df_tip : 908915
# </div>

# %%
print("df_user : "+ str(df_user.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">df_user : 1987897
# </div>

# %% [markdown]
# Extract YEAR and MONTH from datetime

# %%
from pyspark.sql import functions as f
df_tip = df_tip.withColumn("tip_year",f.year(f.to_date(f.col("date"))))
df_tip = df_tip.withColumn("tip_month",f.month(f.to_date(f.col("date"))))

display(df_tip)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# Partition Dataset tip by date column

# %%
df_tip.write.mode("overwrite").partitionBy("tip_year","tip_month")\
.parquet("abfss://yelpdataset@stgrpgroupd.dfs.core.windows.net/tip_partitioned_by_year_and_month/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# repartition() and coalesce()

# %%
print("current number of partitions : "+ str(df_user.rdd.getNumPartitions()))

df_reducr_part = df_user.coalesce(10)
print("current number of partitions after coalesce: "+ str(df_reducr_part.rdd.getNumPartitions()))

df_increased_df = df_user.repartition(30)
print("current number of partitions after repartition : "+ str(df_increased_df.rdd.getNumPartitions()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">current number of partitions : 25
# current number of partitions after coalesce: 10
# current number of partitions after repartition : 30
# </div>

# %%
df_user.coalesce(10).write.mode('overwrite').parquet("abfss://yelpdataset@stgrpgroupd.dfs.core.windows.net/coalesce/user.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_user.repartition(10).write.mode('overwrite').parquet("abfss://yelpdataset@stgrpgroupd.dfs.core.windows.net/repartition/user.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_user = spark.read.parquet("abfss://yelpdataset@stgrpgroupd.dfs.core.windows.net/repartition/user.parquet")
display(df_user)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_user.createOrReplaceTempView("user")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Find the top 3 users based on their total number or reviews:

# %%
# %sql
select user_id,name,review_count from user order by review_count desc limit 3;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th>name</th><th>review_count</th></tr></thead><tbody><tr><td>Hi10sGSZNxQH3NLyWSZ1oA</td><td>Fox</td><td>17473</td></tr><tr><td>8k3aO-mPeyhbR5HUucA5aA</td><td>Victor</td><td>16978</td></tr><tr><td>hWDybu_KvYLSdEFzGrniTw</td><td>Bruce</td><td>16567</td></tr></tbody></table></div>

# %% [markdown]
# Find the top 10 users with the most fans:

# %%
# %sql
select user_id,name,fans from user order by fans desc limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(df_business)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# Analyse top 10 Categories by number of reviews

# %%
from pyspark.sql import Window
df_business_cat = df_business.groupBy("categories").agg(f.count("review_count").alias("Total_review_count"))
df_top_categories = df_business_cat.withColumn("rnk",f.row_number().over(Window.orderBy(f.col('Total_review_count').desc())))
df_top_categories = df_top_categories.filter(f.col('rnk')<=10)
display(df_top_categories)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_business.createOrReplaceTempView("business")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select categories,total_review_count from (
     select business_categories.*,
     ROW_NUMBER() OVER (ORDER BY total_review_count DESC) rn
     FROM (select categories,count(review_count) as total_review_count from business group by categories ) business_categories
     ) where rn <=10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>categories</th><th>total_review_count</th></tr></thead><tbody><tr><td>Beauty & Spas, Nail Salons</td><td>1012</td></tr><tr><td>Restaurants, Pizza</td><td>935</td></tr><tr><td>Nail Salons, Beauty & Spas</td><td>934</td></tr><tr><td>Pizza, Restaurants</td><td>823</td></tr><tr><td>Restaurants, Mexican</td><td>728</td></tr><tr><td>Restaurants, Chinese</td><td>708</td></tr><tr><td>Mexican, Restaurants</td><td>672</td></tr><tr><td>Chinese, Restaurants</td><td>651</td></tr><tr><td>Food, Coffee & Tea</td><td>508</td></tr><tr><td>Beauty & Spas, Hair Salons</td><td>493</td></tr></tbody></table></div>

# %% [markdown]
# Analyse top Businees which have over 1000 Reviews

# %%
df_business_review = df_business.groupBy("categories").agg(f.count("review_count").alias("total_review_count"))
df_top_business = df_business_review.filter(df_business_review.total_review_count >=900).orderBy(f.desc("total_review_count"))
display(df_top_business)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>categories</th><th>total_review_count</th></tr></thead><tbody><tr><td>Beauty & Spas, Nail Salons</td><td>1012</td></tr><tr><td>Restaurants, Pizza</td><td>935</td></tr><tr><td>Nail Salons, Beauty & Spas</td><td>934</td></tr></tbody></table></div>

# %% [markdown]
# Analyse Business Data: Number of restaurants per state

# %%
df_number_of_restaurants = df_business.select("state").groupBy("state").count().orderBy(f.desc("count"))
display(df_number_of_restaurants)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_business.createOrReplaceTempView("business_restaurants")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Analyze top 3 restaurants in each state

# %%
# %sql 
select * from (
    select state,name, review_count,
    ROW_NUMBER() OVER(PARTITION BY state order by review_count desc ) rn 
    from business_restaurants 
    ) where rn<=3;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# List the top restaurants in a state by the number of reviews

# %%
df_business_arizona = df_business.filter(df_business.state=="AZ")
df_arizona = df_business_arizona.groupBy('name').agg(f.count("review_count").alias("total_review_count"))
window = Window.orderBy(df_arizona.total_review_count.desc())
df_arizona_best_rest = df_arizona.select("*",f.rank().over(window).alias("rank")).filter(f.col('rank')<=10) 
display(df_arizona_best_rest)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>total_review_count</th><th>rank</th></tr></thead><tbody><tr><td>Starbucks</td><td>63</td><td>1</td></tr><tr><td>Subway</td><td>50</td><td>2</td></tr><tr><td>Walgreens</td><td>44</td><td>3</td></tr><tr><td>McDonald's</td><td>41</td><td>4</td></tr><tr><td>eegee's</td><td>27</td><td>5</td></tr><tr><td>The UPS Store</td><td>26</td><td>6</td></tr><tr><td>Circle K</td><td>24</td><td>7</td></tr><tr><td>Burger King</td><td>23</td><td>8</td></tr><tr><td>Taco Bell</td><td>22</td><td>9</td></tr><tr><td>Supercuts</td><td>21</td><td>10</td></tr></tbody></table></div>

# %% [markdown]
# Numbers of restaurants in Arizona state per city

# %%
df_business_arizona = df_business.filter(df_business.state=="AZ")
df_business_arizona = df_business_arizona.groupBy('city').count().orderBy(f.desc('count'))
display(df_business_arizona)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# Select City with highest number of restaurants

# %%
window = Window.orderBy(df_business_arizona['count'].desc())
df_city_with_max_rest = df_business_arizona \
                        .select('*',f.rank().over(window).alias('rank')) \
                        .filter(f.col('rank')<=1).drop('rank')
display(df_city_with_max_rest)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>count</th></tr></thead><tbody><tr><td>Tucson</td><td>9249</td></tr></tbody></table></div>

# %% [markdown]
# Broadcast Join

# %%
from pyspark.sql.functions import broadcast 

df_best_rest = df_business.join(broadcast(df_city_with_max_rest),'city','inner')
df_best_rest = df_best_rest.groupBy("name","stars").agg(f.count("review_count").alias("total_review_count"))
df_best_rest = df_best_rest.filter(df_best_rest["total_review_count"]>=10 )
df_best_rest = df_best_rest.filter(df_best_rest["stars"]>=3)
display(df_best_rest)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>stars</th><th>total_review_count</th></tr></thead><tbody><tr><td>Starbucks</td><td>3.5</td><td>15</td></tr><tr><td>eegee's</td><td>3.5</td><td>12</td></tr><tr><td>eegee's</td><td>3.0</td><td>10</td></tr><tr><td>Walgreens</td><td>3.0</td><td>10</td></tr><tr><td>Subway</td><td>3.5</td><td>12</td></tr><tr><td>Subway</td><td>3.0</td><td>13</td></tr><tr><td>Starbucks</td><td>3.0</td><td>13</td></tr><tr><td>Starbucks</td><td>4.0</td><td>13</td></tr></tbody></table></div>

# %% [markdown]
# Most rated Italian restaurant in Tucson

# %%
df_business_Tucson = df_business.filter(df_business.city == 'Tucson')
df_Tucson_italian = df_business_Tucson.filter(df_business_Tucson.categories.contains('Italian'))

df_Tucson_italian = df_Tucson_italian.groupBy('name').agg(f.count('review_count').alias('total_review_count'))
df_Tucson_italian = df_Tucson_italian.filter(df_Tucson_italian.total_review_count >=5)

display(df_Tucson_italian)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>total_review_count</th></tr></thead><tbody><tr><td>Pizza Hut</td><td>14</td></tr><tr><td>Domino's Pizza</td><td>5</td></tr></tbody></table></div>
